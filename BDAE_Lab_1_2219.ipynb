# %% [markdown]
# Name:-Rutuja Dere
#
# PRN:20230802219
#
# Batch:C2
#
# Lab 1
#
# Problem Statement:-
# Banks generate large amounts of structured customer and financial data, but without proper analysis, this data does not provide actionable insights. To support effective decision-making in areas such as customer segmentation, credit risk evaluation, loan approval strategies, and business growth, it is essential to study this data using analytical techniques.
#
# The objective of this study is to perform Exploratory Data Analysis (EDA) on a Banking Dataset using Python, NumPy, Pandas, Matplotlib, and Seaborn. The analysis aims to understand the structure, trends, and patterns within the dataset through:
#
# Data cleaning and preprocessing
# Statistical analysis and summary reporting
# Visualization of customer demographics, loan status, and account features
# Identifying hidden relationships, correlations, and behavioral insights
#
# The findings from the EDA will help uncover meaningful insights such as key indicators of loan approval or rejection, customer financial behavior trends, and factors influencing risk. These insights can support banks in improving decision-making, enhancing customer services, and optimizing performance.

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('bank_marketing_updated_v1.csv')

# %%
data.head()
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
# ...

# %%
data = pd.read_csv('bank_marketing_updated_v1.csv',skiprows=2)
data.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
data.drop('customerid',axis=1,inplace=True)
data.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# ...

# %%
data['job']=data.jobedu.apply(lambda x: x.split(',')[0])
data.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           job
# ...

# %%
data['education']=data.jobedu.apply(lambda x: x.split(',')[1])
data.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           job  education
# ...

# %%
data.drop('jobedu',axis=1,inplace=True)
data.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# 2  may, 2017   76 sec         1     -1         0  unknown       no
# 3  may, 2017   92 sec         1     -1         0  unknown       no
# 4  may, 2017  198 sec         1     -1         0  unknown       no
#
#             job  education
# 0    management   tertiary
# 1    technician  secondary
# ...

# %%
data[['month', 'year']] = data['month'].str.split(',', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 data[['month', 'year']] = data['month'].str.split(',', expand=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
# ...

# %%
missing_count = data.isnull().sum()
print(missing_count)
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %%
data.shape
# Out:
# (45211, 19)

# %%
mean_age = data['age'].mean()
data['age'].fillna(mean_age,inplace=True)
#round of into whole number
data['age'].fillna(round(mean_age), inplace=True)

# %%
missing_count = data.isnull().sum()
print(missing_count)
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %%
mode_month = data['month'].mode()[0]
data['month'].fillna(mode_month, inplace=True)

# %%
mode_response = data['response'].mode()[0]
data['response'].fillna(mode_response, inplace=True)

# %%
missing_count = data.isnull().sum()
print(missing_count)
# Out:
# age          0
# salary       0
# balance      0
# marital      0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response     0
# job          0
# education    0
# dtype: int64

# %%
data.describe()
# Out:
#                 age         salary        balance           day      campaign  \
# count  45211.000000   45211.000000   45211.000000  45211.000000  45211.000000
# mean      40.935651   57006.171065    1362.272058     15.806419      2.763841
# std       10.616848   32085.718415    3044.765829      8.322476      3.098021
# min       18.000000       0.000000   -8019.000000      1.000000      1.000000
# 25%       33.000000   20000.000000      72.000000      8.000000      1.000000
# 50%       39.000000   60000.000000     448.000000     16.000000      2.000000
# 75%       48.000000   70000.000000    1428.000000     21.000000      3.000000
# max       95.000000  120000.000000  102127.000000     31.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
data.pdays.describe()
# Out:
# count    45211.000000
# mean        40.197828
# std        100.128746
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %%
data.replace(-1,np.nan, inplace=True)

# %%
data.pdays.describe()
# Out:
# count    8257.000000
# mean      224.577692
# std       115.344035
# min         1.000000
# 25%       133.000000
# 50%       194.000000
# 75%       327.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
data.dropna(inplace=True)

# %%
data.pdays.describe()
# Out:
# count    8251.000000
# mean      224.550479
# std       115.330796
# min         1.000000
# 25%       133.000000
# 50%       194.000000
# 75%       327.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
data.age.plot.hist()
plt.plot()
# Out:
# []

# %%
sns.boxplot(x=data['age'])
plt.show()

# %%
data.salary.describe()
# Out:
# count      8251.000000
# mean      57567.082778
# std       31793.739844
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
sns.boxplot(x=data['salary'])
plt.show()

# %%
data.salary.plot.hist()
plt.plot()
# Out:
# []

# %%
data.balance.plot.hist()
plt.plot()
# Out:
# []

# %%
sns.boxplot(x=data['balance'])
plt.show()

# %%
data.day.plot.hist()
plt.plot()
# Out:
# []

# %%
sns.boxplot(x=data['day'])
plt.show()

# %%
data.marital.value_counts(normalize=True).plot.barh()
plt.show()

# %%
data.job.value_counts(normalize=True).plot.barh()
plt.show()

# %%
data.education.value_counts(normalize=True).plot.pie()
plt.show()

# %%
data.response.value_counts(normalize=True).plot.pie()
plt.show()

# %%
data.dtypes
# Out:
# age          float64
# salary         int64
# balance      float64
# marital       object
# targeted      object
# default       object
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration      object
# campaign       int64
# pdays        float64
# previous       int64
# poutcome      object
# response      object
# job           object
# education     object
# dtype: object

# %%
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Numerical columns:", numerical_cols)
# Out:
# Numerical columns: ['age', 'salary', 'balance', 'day', 'campaign', 'pdays', 'previous']

# %%
categorical_cols = data.select_dtypes(include=['object', 'category']).columns.tolist()
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: ['marital', 'targeted', 'default', 'housing', 'loan', 'contact', 'month', 'duration', 'poutcome', 'response', 'job', 'education']

# %%
data.groupby('education')['balance'].mean().plot(kind='bar')
plt.title('Average Balance by Education')
plt.ylabel('Balance')
plt.xlabel('Education')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='education', y='balance', data=data)
plt.title('Balance Distribution by Education Level')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'tertiary'),
#   Text(1, 0, 'secondary'),
#   Text(2, 0, 'primary'),
#   Text(3, 0, 'unknown')])

# %%
pd.crosstab(data['education'], data['response'], normalize='index').plot(kind='bar', stacked=True)
plt.title('Response Rate by Education Level')
plt.xlabel('Education')
plt.ylabel('Proportion')
plt.xticks(rotation=45)
plt.show()

# %%
sns.heatmap(cross_tab, annot=True, cmap='coolwarm', fmt='d')
plt.title('Education vs Response Heatmap')
plt.ylabel('Education')
plt.xlabel('Response')
plt.show()

# %%
sns.scatterplot(x='age', y='balance', data=data)
plt.title('Age vs Balance')
plt.xlabel('Age')
plt.ylabel('Balance')
# Out:
# Text(0, 0.5, 'Balance')

# %%
correlation = data[['age', 'balance']].corr()
print(correlation)
# Out:
#              age  balance
# age      1.00000  0.11533
# balance  0.11533  1.00000

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(data[['age', 'balance']], hue='age')
plt.suptitle('Pair Plot Colored by age', y=1.02)
plt.show()

# %% [markdown]
# Conclusion
#
# The EDA on the banking dataset helped uncover important patterns in customer demographics and loan behavior. Using Python and data visualization tools, meaningful insights were obtained that can support better decision-making in customer management, loan approval, and risk assessment. Overall, the analysis shows that data-driven evaluation can improve banking performance and strategy.
